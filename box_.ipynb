# %% [markdown]
# <a href="https://colab.research.google.com/github/shivakumar0001/AD/blob/main/box_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Outliers are data points that differ significantly from other observations in a dataset. In Python, you can identify and handle outliers using libraries like pandas, numpy, and scipy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(10)
data = pd.DataFrame({
    'value': np.concatenate([np.random.normal(0, 1, 100), np.random.normal(10, 1, 100)])
    })

# Calculate the IQR for box plot-based outlier detection
Q1 = data['value'].quantile(0.25)
Q3 = data['value'].quantile(0.75)
IQR = Q3 - Q1

# Define outlier threshold
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = data[(data['value'] < lower_bound) | (data['value'] > upper_bound)]

print("Outliers:\n", outliers)

# Visualize the data with box plot and violin plot
plt.figure(figsize=(12, 6))

# Box plot
plt.subplot(1, 2, 1)
sns.boxplot(x=data['value'])
plt.title('Box Plot to Identify Outliers')

# Violin plot
plt.subplot(1, 2, 2)
sns.violinplot(x=data['value'])
plt.title('Violin Plot')

plt.show()
# Out:
# Outliers:
#  Empty DataFrame
# Columns: [value]
# Index: []
